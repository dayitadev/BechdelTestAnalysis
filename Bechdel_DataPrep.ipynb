# %%
# imports
import urllib, json
import pandas as pd

# %%
df = pd.read_json('http://bechdeltest.com/api/v1/getAllMovies')

# %%
df.count()
# Out:
# imdbid    8796
# year      8796
# rating    8796
# title     8796
# id        8796
# dtype: int64

# %%
import gender_guesser.detector as gender
d = gender.Detector()

# %%
print(d.get_gender("Jennifer"))
# Out:
# female

# %%
movies = pd.read_csv(r'/Users/dayitadev/Documents/Career/BechdelTest/IMDbmovies.csv')
names = pd.read_csv(r'/Users/dayitadev/Documents/Career/BechdelTest/IMDbnames.csv')
ratings = pd.read_csv(r'/Users/dayitadev/Documents/Career/BechdelTest/IMDbratings.csv')

# %%
movies.count()
# Out:
# imdb_title_id            85855
# title                    85855
# original_title           85855
# year                     85855
# date_published           85855
# genre                    85855
# duration                 85855
# country                  85791
# language                 85022
# director                 85768
# writer                   84283
# production_company       81400
# actors                   85786
# description              83740
# avg_vote                 85855
# votes                    85855
# budget                   23710
# usa_gross_income         15326
# worlwide_gross_income    31016
# metascore                13305
# reviews_from_users       78258
# reviews_from_critics     74058
# dtype: int64

# %%
# extract director first names in movies
df.dtypes
# Out:
# imdbid    object
# year       int64
# rating     int64
# title     object
# id         int64
# dtype: object

# %%
# Left join IMDb information to Bechdel Test data
movies['imdbid'] = movies['imdb_title_id'].str[2:]
movies_df = df.merge(movies, left_on='imdbid', right_on='imdbid', how='inner')

# %%
movies.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
# ...

# %%
movies_df.head()
# Out:
#     imdbid  year_x  rating                       title_x    id imdb_title_id  \
# 0  0000574    1906       1  Story of the Kelly Gang, The  1349     tt0000574
# 1  0002101    1912       2                     Cleopatra  2003     tt0002101
# 2  0003973    1914       2         A Florida Enchantment  4457     tt0003973
# 3  0004972    1915       2        Birth of a Nation, The  1258     tt0004972
# 4  0007361    1916       3                    Snow White  7004     tt0007361
#
#                        title_y               original_title year_y  \
# 0  The Story of the Kelly Gang  The Story of the Kelly Gang   1906
# 1                    Cleopatra                    Cleopatra   1912
# 2        A Florida Enchantment        A Florida Enchantment   1914
# 3       Nascita di una nazione        The Birth of a Nation   1915
# 4                   Snow White                   Snow White   1916
#
#   date_published  ...                                             actors  \
# ...

# %%
movies_final = movies_df.loc[(movies_df['year_x'] >= 1960)]

# %%
movies_final.head()
# Out:
#       imdbid  year_x  rating                 title_x    id imdb_title_id  \
# 755  0054167    1960       2             Peeping Tom  6796     tt0054167
# 756  0053804    1960       3                  Exodus  2144     tt0053804
# 757  0053472    1960       0       A bout de souffle   799     tt0053472
# 758  0054047    1960       0  Magnificent Seven, The  1295     tt0054047
# 759  0053719    1960       3   City of the Dead, The  3634     tt0053719
#
#                      title_y         original_title year_y date_published  \
# 755      L'occhio che uccide            Peeping Tom   1960     1960-11-29
# 756                   Exodus                 Exodus   1960     1961-04-29
# 757  Fino all'ultimo respiro      À bout de souffle   1960     1960-09-30
# 758        I magnifici sette  The Magnificent Seven   1960     1961-03-01
# 759       La città dei morti   The City of the Dead   1960     1960-09-01
#
#      ...                                             actors  \
# ...

# %%
movies_final.count()
# Out:
# imdbid                   7100
# year_x                   7100
# rating                   7100
# title_x                  7100
# id                       7100
# imdb_title_id            7100
# title_y                  7100
# original_title           7100
# year_y                   7100
# date_published           7100
# genre                    7100
# duration                 7100
# country                  7099
# language                 7092
# director                 7100
# writer                   7094
# production_company       7057
# actors                   7100
# description              7082
# avg_vote                 7100
# votes                    7100
# budget                   4774
# usa_gross_income         5205
# worlwide_gross_income    5952
# metascore                5277
# reviews_from_users       7062
# reviews_from_critics     7071
# dtype: int64

# %%
movies_final.to_csv('movies.csv', index=False)
